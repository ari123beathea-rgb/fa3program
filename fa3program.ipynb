# %% [markdown]
# <a href="https://colab.research.google.com/github/ari123beathea-rgb/fa3program/blob/main/fa3program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

name = (input ("Name: "))
age = (input ("Age: "))
course = (input ("Course: "))
# Out:
# Name: gnh
# Age: gh
# Course: gh

# %%
#fa3prog2

score = int(input ("Exam Score:"))

if score >= 75:
  print ("Passed")

else:
  print ("Failed")
# Out:
# Exam Score:90
# Passed

# %%
#fa3prog3

name = (input ("Name: "))
score = int(input ("Score: "))

if score >= 90 and score <= 100:
  print ("A")

elif score >= 80 and score <= 89:
  print ("B")

elif score >=70 and score <= 79:
  print ("C")

else:
  print ("F")
